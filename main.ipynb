# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import glob
import tqdm
from PIL import Image

# %%
def get_set_filenames(split_path:str):
    with open(split_path, "r") as f:
        return f.read().split("\n")

def load_label_json(filename):
    with open(filename, "r") as f:
        return json.load(f)

# %% [markdown]
# ### Explore Dataset

# %%
labels_folder_path = "data\\mapillary\\annotations\\"
images_folder_path = "data\\mapillary\\images\\"
splits_folder_path = "data\\mapillary\\splits\\"

# %%
all_labels_paths = glob.glob(f"{labels_folder_path}*.json")
all_images_paths = glob.glob(f"{images_folder_path}*.jpg")

print("Number of found labels:", len(all_labels_paths))
print("Number of found images:", len(all_images_paths))

print()
if len(all_labels_paths) != len(all_images_paths):
    print("Synchronization needed!")
print()
    
train_names = get_set_filenames(f"{splits_folder_path}train.txt")
val_names = get_set_filenames(f"{splits_folder_path}val.txt")
test_names = get_set_filenames(f"{splits_folder_path}test.txt")

print("Number of train files:", len(train_names))
print("Number of val files:", len(val_names))
print("Number of test files:", len(test_names))

total_number_of_files = len(train_names) + len(val_names) + len(test_names)

print()
if total_number_of_files != len(all_images_paths):
    print("Synchronization needed!")
print() 

labels_names = set(map(lambda x: x.split("\\")[-1].replace(".json", ""), all_labels_paths))
images_names = set(map(lambda x: x.split("\\")[-1].replace(".jpg", ""), all_images_paths))
common_names = images_names & labels_names
print("Number of valid image/label pairs:", len(common_names))

available_train_names = set(train_names) & common_names
available_val_names = set(val_names) & common_names
available_test_names = set(test_names) & common_names
print("Number of valid train image/label pairs:", len(available_train_names))
print("Number of valid val image/label pairs:", len(available_val_names))
print("Number of valid test image/label pairs:", len(available_test_names))
# Out:
# Number of found labels: 41909
# Number of found images: 52453
#
# Synchronization needed!
#
# Number of train files: 36589
# Number of val files: 5320
# Number of test files: 10544
#
#
# Number of valid image/label pairs: 41909
# Number of valid train image/label pairs: 36589
# Number of valid val image/label pairs: 5320
# Number of valid test image/label pairs: 0

# %% [markdown]
# ## Setup Dataset

# %%
IMAGE_SIZE = (512, 512)

# %% [markdown]
# ### Create YAML file

# %%
all_labels = set()

for label_path in tqdm.tqdm(all_labels_paths, position=0):
    label_dict = load_label_json(label_path)
    all_labels = all_labels.union(all_labels.union(set([i['label'] for i in label_dict['objects']])))

label_map = {lbl:i for i, lbl in enumerate(all_labels)}
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41909/41909 [03:20<00:00, 208.97it/s]

# %%
# Get only one variant per sign
set(["--".join(i.split("--")[:2]) for i in label_map.keys()])
# Out:
# {'complementary--accident-area',
#  'complementary--both-directions',
#  'complementary--buses',
#  'complementary--chevron-left',
#  'complementary--chevron-right',
#  'complementary--chevron-right-unsure',
#  'complementary--distance',
#  'complementary--except-bicycles',
#  'complementary--extent-of-prohibition-area-both-direction',
#  'complementary--go-left',
#  'complementary--go-right',
#  'complementary--keep-left',
#  'complementary--keep-right',
#  'complementary--maximum-speed-limit-15',
#  'complementary--maximum-speed-limit-20',
#  'complementary--maximum-speed-limit-25',
#  'complementary--maximum-speed-limit-30',
#  'complementary--maximum-speed-limit-35',
#  'complementary--maximum-speed-limit-40',
#  'complementary--maximum-speed-limit-45',
#  'complementary--maximum-speed-limit-50',
#  'complementary--maximum-speed-limit-55',
#  'complementary--maximum-speed-limit-70',
#  'complementary--maximum-speed-limit-75',
#  'complementary--obstacle-delineator',
#  'complementary--one-direction-left',
#  'complementary--one-direction-right',
#  'complementary--pass-right',
#  'complementary--priority-route-at-intersection',
#  'complementary--tow-away-zone',
#  'complementary--trucks',
#  'complementary--trucks-turn-right',
#  'complementary--turn-left',
#  'complementary--turn-right',
#  'information--airport',
#  'information--bike-route',
#  'information--bus-stop',
#  'information--camp',
#  'information--central-lane',
#  'information--children',
#  'information--dead-end',
#  'information--dead-end-except-bicycles',
#  'information--disabled-persons',
#  'information--emergency-facility',
#  'information--end-of-built-up-area',
#  'information--end-of-limited-access-road',
#  'information--end-of-living-street',
#  'information--end-of-motorway',
#  'information--end-of-pedestrians-only',
#  'information--food',
#  'information--gas-station',
#  'information--highway-exit',
#  'information--highway-interstate-route',
#  'information--hospital',
#  'information--interstate-route',
#  'information--limited-access-road',
#  'information--living-street',
#  'information--lodging',
#  'information--minimum-speed-40',
#  'information--motorway',
#  'information--no-parking',
#  'information--parking',
#  'information--pedestrians-crossing',
#  'information--road-bump',
#  'information--safety-area',
#  'information--stairs',
#  'information--telephone',
#  'information--trailer-camping',
#  'information--tram-bus-stop',
#  'other-sign',
#  'regulatory--bicycles-only',
#  'regulatory--buses-only',
#  'regulatory--detour-left',
#  'regulatory--do-not-block-intersection',
#  'regulatory--do-not-stop-on-tracks',
#  'regulatory--dual-lanes-go-straight-on-left',
#  'regulatory--dual-lanes-go-straight-on-right',
#  'regulatory--dual-lanes-turn-left-no-u-turn',
#  'regulatory--dual-lanes-turn-left-or-straight',
#  'regulatory--dual-lanes-turn-right-or-straight',
#  'regulatory--dual-path-bicycles-and-pedestrians',
#  'regulatory--dual-path-pedestrians-and-bicycles',
#  'regulatory--end-of-bicycles-only',
#  'regulatory--end-of-buses-only',
#  'regulatory--end-of-maximum-speed-limit-30',
#  'regulatory--end-of-maximum-speed-limit-70',
#  'regulatory--end-of-no-parking',
#  'regulatory--end-of-priority-road',
#  'regulatory--end-of-prohibition',
#  'regulatory--end-of-speed-limit-zone',
#  'regulatory--give-way-to-oncoming-traffic',
#  'regulatory--go-straight',
#  'regulatory--go-straight-or-turn-left',
#  'regulatory--go-straight-or-turn-right',
#  'regulatory--height-limit',
#  'regulatory--keep-left',
#  'regulatory--keep-right',
#  'regulatory--lane-control',
#  'regulatory--left-turn-yield-on-green',
#  'regulatory--maximum-speed-limit-10',
#  'regulatory--maximum-speed-limit-100',
#  'regulatory--maximum-speed-limit-110',
#  'regulatory--maximum-speed-limit-120',
#  'regulatory--maximum-speed-limit-15',
#  'regulatory--maximum-speed-limit-20',
#  'regulatory--maximum-speed-limit-25',
#  'regulatory--maximum-speed-limit-30',
#  'regulatory--maximum-speed-limit-35',
#  'regulatory--maximum-speed-limit-40',
#  'regulatory--maximum-speed-limit-45',
#  'regulatory--maximum-speed-limit-5',
#  'regulatory--maximum-speed-limit-50',
#  'regulatory--maximum-speed-limit-55',
#  'regulatory--maximum-speed-limit-60',
#  'regulatory--maximum-speed-limit-65',
#  'regulatory--maximum-speed-limit-70',
#  'regulatory--maximum-speed-limit-80',
#  'regulatory--maximum-speed-limit-90',
#  'regulatory--maximum-speed-limit-led-100',
#  'regulatory--maximum-speed-limit-led-60',
#  'regulatory--maximum-speed-limit-led-80',
#  'regulatory--minimum-safe-distance',
#  'regulatory--mopeds-and-bicycles-only',
#  'regulatory--no-bicycles',
#  'regulatory--no-buses',
#  'regulatory--no-entry',
#  'regulatory--no-hawkers',
#  'regulatory--no-heavy-goods-vehicles',
#  'regulatory--no-heavy-goods-vehicles-or-buses',
#  'regulatory--no-left-turn',
#  'regulatory--no-mopeds-or-bicycles',
#  'regulatory--no-motor-vehicle-trailers',
#  'regulatory--no-motor-vehicles',
#  'regulatory--no-motor-vehicles-except-motorcycles',
#  'regulatory--no-motorcycles',
#  'regulatory--no-overtaking',
#  'regulatory--no-overtaking-by-heavy-goods-vehicles',
#  'regulatory--no-parking',
#  'regulatory--no-parking-or-no-stopping',
#  'regulatory--no-pedestrians',
#  'regulatory--no-pedestrians-or-bicycles',
#  'regulatory--no-right-turn',
#  'regulatory--no-stopping',
#  'regulatory--no-straight-through',
#  'regulatory--no-turn-on-red',
#  'regulatory--no-turns',
#  'regulatory--no-u-turn',
#  'regulatory--no-vehicles-carrying-dangerous-goods',
#  'regulatory--one-way-left',
#  'regulatory--one-way-right',
#  'regulatory--one-way-straight',
#  'regulatory--parking-restrictions',
#  'regulatory--pass-on-either-side',
#  'regulatory--passing-lane-ahead',
#  'regulatory--pedestrians-only',
#  'regulatory--priority-over-oncoming-vehicles',
#  'regulatory--priority-road',
#  'regulatory--radar-enforced',
#  'regulatory--reversible-lanes',
#  'regulatory--road-closed',
#  'regulatory--road-closed-to-vehicles',
#  'regulatory--roundabout',
#  'regulatory--shared-path-bicycles-and-pedestrians',
#  'regulatory--shared-path-pedestrians-and-bicycles',
#  'regulatory--stop',
#  'regulatory--stop-here-on-red-or-flashing-light',
#  'regulatory--stop-signals',
#  'regulatory--text-four-lines',
#  'regulatory--triple-lanes-turn-left-center-lane',
#  'regulatory--truck-speed-limit-60',
#  'regulatory--turn-left',
#  'regulatory--turn-left-ahead',
#  'regulatory--turn-right',
#  'regulatory--turn-right-ahead',
#  'regulatory--turning-vehicles-yield-to-pedestrians',
#  'regulatory--u-turn',
#  'regulatory--weight-limit',
#  'regulatory--weight-limit-with-trucks',
#  'regulatory--width-limit',
#  'regulatory--wrong-way',
#  'regulatory--yield',
#  'warning--accidental-area-unsure',
#  'warning--added-lane-right',
#  'warning--bicycles-crossing',
#  'warning--bus-stop-ahead',
#  'warning--children',
#  'warning--crossroads',
#  'warning--crossroads-with-priority-to-the-right',
#  'warning--curve-left',
#  'warning--curve-right',
#  'warning--dip',
#  'warning--divided-highway-ends',
#  'warning--domestic-animals',
#  'warning--double-curve-first-left',
#  'warning--double-curve-first-right',
#  'warning--double-reverse-curve-right',
#  'warning--double-turn-first-right',
#  'warning--dual-lanes-right-turn-or-go-straight',
#  'warning--emergency-vehicles',
#  'warning--equestrians-crossing',
#  'warning--falling-rocks-or-debris-right',
#  'warning--flaggers-in-road',
#  'warning--hairpin-curve-left',
#  'warning--hairpin-curve-right',
#  'warning--height-restriction',
#  'warning--horizontal-alignment-left',
#  'warning--horizontal-alignment-right',
#  'warning--junction-with-a-side-road-acute-left',
#  'warning--junction-with-a-side-road-acute-right',
#  'warning--junction-with-a-side-road-perpendicular-left',
#  'warning--junction-with-a-side-road-perpendicular-right',
#  'warning--kangaloo-crossing',
#  'warning--loop-270-degree',
#  'warning--narrow-bridge',
#  'warning--offset-roads',
#  'warning--other-danger',
#  'warning--pass-left-or-right',
#  'warning--pedestrian-stumble-train',
#  'warning--pedestrians-crossing',
#  'warning--playground',
#  'warning--railroad-crossing',
#  'warning--railroad-crossing-with-barriers',
#  'warning--railroad-crossing-without-barriers',
#  'warning--railroad-intersection',
#  'warning--restricted-zone',
#  'warning--road-bump',
#  'warning--road-narrows',
#  'warning--road-narrows-left',
#  'warning--road-narrows-right',
#  'warning--road-widens',
#  'warning--road-widens-right',
#  'warning--roadworks',
#  'warning--roundabout',
#  'warning--school-zone',
#  'warning--shared-lane-motorcycles-bicycles',
#  'warning--slippery-motorcycles',
#  'warning--slippery-road-surface',
#  'warning--steep-ascent',
#  'warning--stop-ahead',
#  'warning--t-roads',
#  'warning--texts',
#  'warning--traffic-merges-left',
#  'warning--traffic-merges-right',
#  'warning--traffic-signals',
#  'warning--trail-crossing',
#  'warning--trams-crossing',
#  'warning--trucks-crossing',
#  'warning--turn-left',
#  'warning--turn-right',
#  'warning--two-way-traffic',
#  'warning--uneven-road',
#  'warning--uneven-roads-ahead',
#  'warning--wild-animals',
#  'warning--winding-road-first-left',
#  'warning--winding-road-first-right',
#  'warning--wombat-crossing',
#  'warning--y-roads'}

# %%
classes_str = ""

for lbl in label_map:
    classes_str += f"  {label_map[lbl]}: {lbl}\n"

training_yaml_file = \
f"""
path: mapillary/
train: 'images/train'
val: 'images/val'
 
# class names
names: 
{classes_str}
""".strip()

with open("mapillary_traffix_sign.yaml", "w") as f:
    f.write(training_yaml_file)

print(training_yaml_file)
# Out:
# path: mapillary/
# train: 'images/train'
# val: 'images/val'
#
# # class names
# names:
#   0: warning--pedestrians-crossing--g11
#   1: regulatory--no-heavy-goods-vehicles-or-buses--g1
#   2: warning--uneven-road--g6
#   3: regulatory--no-right-turn--g1
#   4: regulatory--keep-right--g1
#   5: warning--double-curve-first-right--g2
#   6: warning--t-roads--g2
#   7: warning--bus-stop-ahead--g3
#   8: warning--children--g1
#   9: information--pedestrians-crossing--g2
#   10: regulatory--one-way-straight--g1
#   11: regulatory--no-stopping--g8
#   12: regulatory--maximum-speed-limit-40--g1
#   13: regulatory--maximum-speed-limit-40--g6
#   14: regulatory--no-motor-vehicles--g1
#   15: regulatory--maximum-speed-limit-20--g1
#   16: complementary--chevron-right--g5
#   17: regulatory--maximum-speed-limit-100--g3
#   18: warning--railroad-crossing--g1
#   19: regulatory--no-entry--g1
#   20: complementary--distance--g3
#   21: warning--two-way-traffic--g1
#   22: warning--wild-animals--g4
#   23: information--tram-bus-stop--g2
#   24: regulatory--no-parking-or-no-stopping--g2
#   25: warning--road-bump--g2
#   26: warning--dip--g2
#   27: regulatory--shared-path-pedestrians-and-bicycles--g1
#   28: regulatory--no-bicycles--g1
#   29: complementary--chevron-left--g4
#   30: regulatory--dual-lanes-go-straight-on-right--g1
#   31: warning--trucks-crossing--g1
#   32: information--disabled-persons--g1
#   33: regulatory--reversible-lanes--g2
#   34: warning--pass-left-or-right--g2
#   35: information--no-parking--g3
#   36: regulatory--dual-path-pedestrians-and-bicycles--g1
#   37: regulatory--dual-lanes-turn-left-no-u-turn--g1
#   38: regulatory--no-turns--g1
#   39: complementary--obstacle-delineator--g2
#   40: warning--road-narrows-left--g2
#   41: regulatory--radar-enforced--g1
#   42: warning--roadworks--g6
#   43: regulatory--keep-right--g2
#   44: warning--junction-with-a-side-road-perpendicular-left--g3
#   45: regulatory--no-heavy-goods-vehicles--g5
#   46: regulatory--no-hawkers--g1
#   47: other-sign
#   48: regulatory--keep-right--g4
#   49: regulatory--no-u-turn--g1
#   50: complementary--pass-right--g1
#   51: regulatory--no-parking-or-no-stopping--g1
#   52: regulatory--no-left-turn--g1
#   53: information--central-lane--g1
#   54: complementary--maximum-speed-limit-15--g1
#   55: regulatory--end-of-speed-limit-zone--g1
#   56: warning--traffic-signals--g3
#   57: warning--turn-right--g2
#   58: regulatory--priority-road--g4
#   59: information--parking--g3
#   60: regulatory--turning-vehicles-yield-to-pedestrians--g1
#   61: information--trailer-camping--g1
#   62: information--bike-route--g1
#   63: complementary--maximum-speed-limit-70--g1
#   64: warning--railroad-intersection--g3
#   65: regulatory--no-straight-through--g1
#   66: regulatory--no-overtaking--g4
#   67: warning--domestic-animals--g1
#   68: warning--roundabout--g1
#   69: regulatory--turn-right-ahead--g1
#   70: warning--roadworks--g4
#   71: complementary--maximum-speed-limit-20--g1
#   72: information--airport--g2
#   73: warning--hairpin-curve-left--g1
#   74: warning--railroad-crossing-without-barriers--g4
#   75: regulatory--no-turn-on-red--g1
#   76: regulatory--no-stopping--g4
#   77: regulatory--no-pedestrians--g3
#   78: regulatory--no-buses--g3
#   79: regulatory--maximum-speed-limit-25--g1
#   80: regulatory--roundabout--g1
#   81: information--stairs--g1
#   82: complementary--chevron-right--g4
#   83: warning--road-narrows--g1
#   84: warning--winding-road-first-right--g1
#   85: regulatory--no-motorcycles--g1
#   86: warning--shared-lane-motorcycles-bicycles--g1
#   87: regulatory--pass-on-either-side--g2
#   88: warning--equestrians-crossing--g2
#   89: warning--double-reverse-curve-right--g1
#   90: regulatory--maximum-speed-limit-50--g1
#   91: complementary--accident-area--g3
#   92: information--end-of-motorway--g1
#   93: complementary--one-direction-right--g1
#   94: regulatory--maximum-speed-limit-100--g1
#   95: warning--dual-lanes-right-turn-or-go-straight--g1
#   96: regulatory--end-of-prohibition--g1
#   97: complementary--chevron-left--g3
#   98: warning--crossroads--g3
#   99: regulatory--triple-lanes-turn-left-center-lane--g1
#   100: warning--crossroads-with-priority-to-the-right--g1
#   101: warning--height-restriction--g2
#   102: regulatory--stop-here-on-red-or-flashing-light--g2
#   103: complementary--chevron-right--g1
#   104: warning--added-lane-right--g1
#   105: warning--falling-rocks-or-debris-right--g2
#   106: warning--roadworks--g2
#   107: regulatory--do-not-stop-on-tracks--g1
#   108: warning--falling-rocks-or-debris-right--g1
#   109: warning--junction-with-a-side-road-perpendicular-right--g1
#   110: regulatory--road-closed--g1
#   111: warning--road-narrows-left--g1
#   112: regulatory--maximum-speed-limit-10--g1
#   113: complementary--trucks--g1
#   114: regulatory--no-overtaking-by-heavy-goods-vehicles--g1
#   115: regulatory--maximum-speed-limit-led-60--g1
#   116: regulatory--no-motorcycles--g2
#   117: regulatory--maximum-speed-limit-110--g1
#   118: information--telephone--g2
#   119: warning--offset-roads--g3
#   120: regulatory--maximum-speed-limit-led-100--g1
#   121: warning--playground--g1
#   122: regulatory--no-bicycles--g3
#   123: regulatory--minimum-safe-distance--g1
#   124: warning--railroad-crossing-with-barriers--g4
#   125: warning--falling-rocks-or-debris-right--g4
#   126: regulatory--bicycles-only--g2
#   127: warning--crossroads--g1
#   128: warning--winding-road-first-right--g3
#   129: regulatory--maximum-speed-limit-80--g1
#   130: regulatory--no-bicycles--g2
#   131: complementary--maximum-speed-limit-50--g1
#   132: regulatory--stop--g10
#   133: regulatory--mopeds-and-bicycles-only--g1
#   134: regulatory--no-pedestrians-or-bicycles--g1
#   135: regulatory--lane-control--g1
#   136: information--end-of-living-street--g1
#   137: regulatory--no-parking--g1
#   138: complementary--go-right--g1
#   139: regulatory--no-motor-vehicles-except-motorcycles--g1
#   140: information--children--g1
#   141: complementary--maximum-speed-limit-45--g1
#   142: regulatory--no-overtaking--g1
#   143: regulatory--one-way-right--g2
#   144: regulatory--no-stopping--g2
#   145: complementary--trucks-turn-right--g1
#   146: regulatory--passing-lane-ahead--g1
#   147: information--highway-exit--g1
#   148: complementary--one-direction-left--g1
#   149: warning--pedestrians-crossing--g5
#   150: regulatory--bicycles-only--g3
#   151: complementary--tow-away-zone--g1
#   152: complementary--keep-left--g1
#   153: warning--turn-left--g1
#   154: warning--pedestrian-stumble-train--g1
#   155: regulatory--end-of-priority-road--g1
#   156: regulatory--yield--g1
#   157: regulatory--no-u-turn--g3
#   158: regulatory--no-vehicles-carrying-dangerous-goods--g1
#   159: warning--roadworks--g3
#   160: regulatory--no-pedestrians--g2
#   161: regulatory--dual-lanes-go-straight-on-left--g1
#   162: regulatory--priority-over-oncoming-vehicles--g1
#   163: information--end-of-built-up-area--g1
#   164: complementary--extent-of-prohibition-area-both-direction--g1
#   165: warning--y-roads--g1
#   166: complementary--priority-route-at-intersection--g1
#   167: complementary--maximum-speed-limit-30--g1
#   168: warning--loop-270-degree--g1
#   169: information--highway-interstate-route--g2
#   170: regulatory--no-motor-vehicle-trailers--g1
#   171: complementary--both-directions--g1
#   172: warning--narrow-bridge--g3
#   173: warning--flaggers-in-road--g1
#   174: warning--railroad-crossing-with-barriers--g2
#   175: regulatory--maximum-speed-limit-120--g1
#   176: regulatory--go-straight--g1
#   177: warning--winding-road-first-left--g2
#   178: warning--winding-road-first-left--g1
#   179: information--telephone--g1
#   180: information--lodging--g1
#   181: regulatory--go-straight-or-turn-right--g3
#   182: regulatory--dual-path-bicycles-and-pedestrians--g1
#   183: warning--children--g2
#   184: regulatory--pedestrians-only--g2
#   185: regulatory--turn-left--g3
#   186: regulatory--end-of-buses-only--g1
#   187: regulatory--wrong-way--g1
#   188: warning--double-turn-first-right--g1
#   189: warning--bicycles-crossing--g3
#   190: warning--railroad-crossing-without-barriers--g3
#   191: warning--road-narrows-right--g1
#   192: regulatory--turn-right-ahead--g2
#   193: warning--other-danger--g1
#   194: regulatory--no-left-turn--g2
#   195: warning--uneven-roads-ahead--g1
#   196: complementary--maximum-speed-limit-25--g1
#   197: warning--trams-crossing--g1
#   198: regulatory--no-motor-vehicles--g4
#   199: information--camp--g1
#   200: information--interstate-route--g1
#   201: regulatory--no-parking-or-no-stopping--g3
#   202: regulatory--dual-lanes-turn-right-or-straight--g1
#   203: regulatory--dual-lanes-turn-left-or-straight--g1
#   204: regulatory--no-left-turn--g3
#   205: regulatory--maximum-speed-limit-50--g6
#   206: regulatory--keep-left--g2
#   207: warning--roadworks--g1
#   208: regulatory--maximum-speed-limit-led-80--g1
#   209: warning--texts--g3
#   210: warning--hairpin-curve-right--g1
#   211: regulatory--no-turn-on-red--g2
#   212: regulatory--one-way-left--g2
#   213: regulatory--road-closed-to-vehicles--g1
#   214: regulatory--road-closed-to-vehicles--g3
#   215: regulatory--truck-speed-limit-60--g1
#   216: regulatory--go-straight--g3
#   217: warning--playground--g3
#   218: regulatory--go-straight-or-turn-left--g3
#   219: warning--pedestrians-crossing--g9
#   220: warning--texts--g2
#   221: warning--railroad-crossing-without-barriers--g1
#   222: warning--bicycles-crossing--g2
#   223: warning--school-zone--g2
#   224: information--dead-end-except-bicycles--g1
#   225: information--safety-area--g2
#   226: warning--traffic-signals--g1
#   227: complementary--chevron-left--g1
#   228: regulatory--weight-limit-with-trucks--g1
#   229: warning--traffic-merges-right--g2
#   230: warning--traffic-merges-left--g1
#   231: warning--other-danger--g3
#   232: complementary--chevron-left--g2
#   233: warning--roundabout--g25
#   234: complementary--maximum-speed-limit-35--g1
#   235: information--dead-end--g1
#   236: regulatory--u-turn--g1
#   237: warning--junction-with-a-side-road-perpendicular-left--g4
#   238: warning--junction-with-a-side-road-perpendicular-right--g3
#   239: information--limited-access-road--g1
#   240: warning--horizontal-alignment-right--g1
#   241: warning--slippery-road-surface--g2
#   242: warning--junction-with-a-side-road-acute-left--g1
#   243: regulatory--pass-on-either-side--g1
#   244: warning--pedestrians-crossing--g4
#   245: information--gas-station--g1
#   246: warning--road-bump--g1
#   247: regulatory--maximum-speed-limit-30--g3
#   248: regulatory--no-parking--g2
#   249: warning--horizontal-alignment-left--g1
#   250: regulatory--parking-restrictions--g2
#   251: regulatory--turn-right--g1
#   252: warning--steep-ascent--g7
#   253: information--pedestrians-crossing--g1
#   254: complementary--buses--g1
#   255: regulatory--no-heavy-goods-vehicles--g1
#   256: regulatory--no-motor-vehicles-except-motorcycles--g2
#   257: warning--road-narrows--g2
#   258: warning--horizontal-alignment-right--g3
#   259: regulatory--no-stopping--g15
#   260: regulatory--shared-path-bicycles-and-pedestrians--g1
#   261: complementary--maximum-speed-limit-55--g1
#   262: regulatory--bicycles-only--g1
#   263: regulatory--no-turn-on-red--g3
#   264: regulatory--end-of-no-parking--g1
#   265: warning--curve-left--g1
#   266: regulatory--one-way-left--g3
#   267: regulatory--no-right-turn--g3
#   268: warning--double-curve-first-left--g1
#   269: information--parking--g5
#   270: warning--stop-ahead--g9
#   271: warning--kangaloo-crossing--g1
#   272: warning--junction-with-a-side-road-acute-right--g1
#   273: warning--junction-with-a-side-road-perpendicular-left--g1
#   274: information--emergency-facility--g2
#   275: warning--slippery-motorcycles--g1
#   276: regulatory--turn-right--g3
#   277: complementary--except-bicycles--g1
#   278: warning--double-curve-first-right--g1
#   279: regulatory--no-heavy-goods-vehicles--g2
#   280: warning--wild-animals--g1
#   281: information--road-bump--g1
#   282: regulatory--maximum-speed-limit-5--g1
#   283: regulatory--turn-left--g2
#   284: regulatory--buses-only--g1
#   285: warning--curve-right--g2
#   286: warning--curve-left--g2
#   287: regulatory--turn-left-ahead--g1
#   288: regulatory--roundabout--g2
#   289: warning--texts--g1
#   290: warning--divided-highway-ends--g2
#   291: regulatory--no-u-turn--g2
#   292: regulatory--maximum-speed-limit-30--g1
#   293: warning--bicycles-crossing--g1
#   294: regulatory--one-way-right--g3
#   295: regulatory--maximum-speed-limit-45--g1
#   296: warning--narrow-bridge--g1
#   297: information--parking--g2
#   298: warning--double-curve-first-left--g2
#   299: warning--pedestrians-crossing--g1
#   300: warning--curve-right--g1
#   301: regulatory--maximum-speed-limit-90--g1
#   302: warning--railroad-crossing--g4
#   303: warning--traffic-merges-right--g1
#   304: information--living-street--g1
#   305: information--parking--g6
#   306: regulatory--keep-left--g1
#   307: warning--uneven-road--g2
#   308: complementary--keep-right--g1
#   309: regulatory--road-closed--g2
#   310: complementary--turn-left--g2
#   311: complementary--distance--g2
#   312: regulatory--width-limit--g1
#   313: complementary--go-left--g1
#   314: regulatory--no-mopeds-or-bicycles--g1
#   315: warning--emergency-vehicles--g1
#   316: regulatory--no-overtaking--g2
#   317: information--parking--g1
#   318: warning--pedestrians-crossing--g12
#   319: regulatory--maximum-speed-limit-60--g1
#   320: regulatory--left-turn-yield-on-green--g1
#   321: regulatory--height-limit--g1
#   322: complementary--distance--g1
#   323: information--gas-station--g3
#   324: complementary--maximum-speed-limit-40--g1
#   325: information--end-of-pedestrians-only--g2
#   326: warning--pass-left-or-right--g1
#   327: information--bus-stop--g1
#   328: warning--traffic-signals--g4
#   329: warning--hairpin-curve-right--g4
#   330: complementary--chevron-left--g5
#   331: regulatory--weight-limit--g1
#   332: warning--traffic-signals--g2
#   333: regulatory--end-of-maximum-speed-limit-30--g2
#   334: regulatory--one-way-left--g1
#   335: regulatory--do-not-block-intersection--g1
#   336: warning--accidental-area-unsure--g2
#   337: regulatory--maximum-speed-limit-65--g2
#   338: information--parking--g45
#   339: warning--railroad-intersection--g4
#   340: regulatory--maximum-speed-limit-25--g2
#   341: warning--railroad-crossing--g3
#   342: information--hospital--g1
#   343: regulatory--maximum-speed-limit-35--g2
#   344: information--airport--g1
#   345: warning--traffic-merges-left--g2
#   346: warning--slippery-road-surface--g1
#   347: regulatory--stop--g1
#   348: warning--road-widens--g1
#   349: warning--divided-highway-ends--g1
#   350: complementary--obstacle-delineator--g1
#   351: complementary--turn-right--g2
#   352: complementary--go-right--g2
#   353: regulatory--give-way-to-oncoming-traffic--g1
#   354: regulatory--end-of-maximum-speed-limit-70--g2
#   355: warning--road-narrows-right--g2
#   356: regulatory--maximum-speed-limit-70--g1
#   357: regulatory--turn-right--g2
#   358: regulatory--end-of-bicycles-only--g1
#   359: regulatory--no-stopping--g5
#   360: regulatory--maximum-speed-limit-45--g3
#   361: regulatory--no-pedestrians--g1
#   362: information--motorway--g1
#   363: regulatory--stop--g2
#   364: warning--two-way-traffic--g2
#   365: regulatory--go-straight-or-turn-left--g2
#   366: complementary--chevron-right--g3
#   367: regulatory--maximum-speed-limit-40--g3
#   368: complementary--chevron-right-unsure--g6
#   369: regulatory--keep-right--g6
#   370: regulatory--no-heavy-goods-vehicles--g4
#   371: regulatory--maximum-speed-limit-15--g1
#   372: regulatory--pedestrians-only--g1
#   373: regulatory--no-parking--g5
#   374: complementary--maximum-speed-limit-75--g1
#   375: warning--t-roads--g1
#   376: information--minimum-speed-40--g1
#   377: regulatory--go-straight-or-turn-left--g1
#   378: regulatory--stop-here-on-red-or-flashing-light--g1
#   379: warning--trail-crossing--g2
#   380: information--end-of-limited-access-road--g1
#   381: warning--railroad-crossing-with-barriers--g1
#   382: regulatory--end-of-maximum-speed-limit-70--g1
#   383: warning--hairpin-curve-left--g3
#   384: warning--wombat-crossing--g1
#   385: warning--domestic-animals--g3
#   386: regulatory--go-straight-or-turn-right--g1
#   387: regulatory--stop-signals--g1
#   388: regulatory--text-four-lines--g1
#   389: regulatory--maximum-speed-limit-55--g2
#   390: regulatory--no-right-turn--g2
#   391: warning--turn-right--g1
#   392: regulatory--no-overtaking--g5
#   393: regulatory--no-straight-through--g2
#   394: regulatory--detour-left--g1
#   395: warning--restricted-zone--g1
#   396: regulatory--turn-left--g1
#   397: warning--road-widens-right--g1
#   398: warning--pedestrians-crossing--g10
#   399: information--food--g2
#   400: regulatory--one-way-right--g1

# %% [markdown]
# ### Populate `labels` folder

# %%
yolo_labels_folder_path = "datasets\\mapillary\\labels\\"

for label_path in tqdm.tqdm(all_labels_paths, position=0):
    filename = label_path.split("\\")[-1].replace(".json", "")

    set_suffix = None
    
    if filename in available_train_names:
        set_suffix = "train\\"

    if filename in available_val_names:
        set_suffix = "val\\"

    if set_suffix is None:
        print("Set of", label_path, "cannot be determined. Skipping...")
        continue
    
    label_dict = load_label_json(label_path)
    w, h = label_dict['width'], label_dict['height']
    label_txt = ""
    
    for obj in label_dict['objects']:
        lbl_indx = label_map[obj['label']]
        x_center = np.mean([obj['bbox']['xmin'], obj['bbox']['xmax']]) / w
        y_center = np.mean([obj['bbox']['ymin'], obj['bbox']['ymax']]) / h
        x_length = (obj['bbox']['xmax'] - obj['bbox']['xmin']) / w
        y_length = (obj['bbox']['ymax'] - obj['bbox']['ymin']) / h
        label_txt += f"{lbl_indx} {x_center} {y_center} {x_length} {y_length}\n"

    label_txt = label_txt.strip()
    filename = yolo_labels_folder_path + set_suffix + label_path.split("\\")[-1].replace(".json", "") + ".txt"

    with open(filename, "w") as f:
        f.write(label_txt)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41909/41909 [03:16<00:00, 212.80it/s]

# %% [markdown]
# ### Populate `images` folder

# %%
import concurrent.futures
import os


def process_and_save_image(image_path):
    filename = image_path.split("\\")[-1].replace(".jpg", "")
    set_suffix = None

    if filename in available_train_names:
        set_suffix = "train\\"
    elif filename in available_val_names:
        set_suffix = "val\\"
    
    if set_suffix is None:
        return

    # Adjusted to use os.path.join for better path handling
    filename = os.path.join(yolo_images_folder_path, set_suffix, filename + ".png").strip()

    image = Image.open(image_path).resize(IMAGE_SIZE)
    image.save(filename)
    image.close()

# Adjust the max_workers as needed
with concurrent.futures.ThreadPoolExecutor(max_workers=500) as executor:
    # List to store futures
    future_to_image = {executor.submit(process_and_save_image, image_path): image_path for image_path in all_images_paths}
    
    # Process futures as they complete
    for future in tqdm.tqdm(concurrent.futures.as_completed(future_to_image), total=len(future_to_image), position=0):
        image_path = future_to_image[future]
        try:
            data = future.result()
        except Exception as exc:
            print('%r generated an exception: %s' % (image_path, exc))

# %%
# yolo_images_folder_path = "datasets\\mapillary\\images\\"

# for image_path in tqdm.tqdm(all_images_paths, position=0):
#     filename = image_path.split("\\")[-1].replace(".jpg", "")

#     set_suffix = None
    
#     if filename in available_train_names:
#         set_suffix = "train\\"

#     if filename in available_val_names:
#         set_suffix = "val\\"

#     if set_suffix is None:
#         continue

#     filename = yolo_images_folder_path + set_suffix + image_path.split("\\")[-1].replace(".json", "") + ".jpg"

#     image = Image.open(image_path).resize(IMAGE_SIZE)
#     image.save(filename)
#     image.close()

# %% [markdown]
# ### Model Training

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('yolov8l.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8l.pt to 'yolov8l.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 83.7M/83.7M [00:07<00:00, 11.2MB/s]

# %%
# Training.
results = model.train(
   data='mapillary_traffix_sign.yaml',
   imgsz=IMAGE_SIZE[0],
   epochs=150,
   batch=8,
   name='yolov8l_mapillary_trafic_signs',
)
# Out:
# New https://pypi.org/project/ultralytics/8.1.24 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.186  Python-3.11.8 torch-2.2.1 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12287MiB)
# engine\trainer: task=detect, mode=train, model=yolov8l.pt, data=mapillary_traffix_sign.yaml, epochs=150, patience=50, batch=8, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=yolov8l_mapillary_trafic_signs, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\yolov8l_mapillary_trafic_signs2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5891971  ultralytics.nn.modules.head.Detect           [401, [256, 512, 512]]
# Model summary: 365 layers, 43939011 parameters, 43938995 gradients, 167.1 GFLOPs
#
# Transferred 595/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# train: Scanning E:\traffic-sign-detection\datasets\mapillary\labels\train.cache... 36589 images, 182 backgrounds, 2 corrupt: 100%|██████████| 36652/36652 [00:00<?, ?it/s]
# train: WARNING  E:\traffic-sign-detection\datasets\mapillary\images\train\7PqhoA2EA5fHwoT_AWQF_Q.jpg: 8 duplicate labels removed
# train: WARNING  E:\traffic-sign-detection\datasets\mapillary\images\train\OENb8BfFyAocFzHHM4Mehg.jpg: ignoring corrupt image/label: negative label values [   -0.97314]
# train: WARNING  E:\traffic-sign-detection\datasets\mapillary\images\train\dtjhRwZcYld3CdbIFmQJaA.jpg: ignoring corrupt image/label: negative label values [   -0.95337]
# val: Scanning E:\traffic-sign-detection\datasets\mapillary\labels\val.cache... 5320 images, 18 backgrounds, 1 corrupt: 100%|██████████| 5326/5326 [00:00<?, ?it/s]
# val: WARNING  E:\traffic-sign-detection\datasets\mapillary\images\val\mw82Ix9zLKMBsOBqASEiDQ.jpg: ignoring corrupt image/label: negative label values [    -0.9624]
# Plotting labels to runs\detect\yolov8l_mapillary_trafic_signs2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs\detect\yolov8l_mapillary_trafic_signs2
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      4.52G      1.321      3.535     0.9089         15        512: 100%|██████████| 4582/4582 [17:47<00:00,  4.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:34<00:00,  3.54it/s]
#                    all       5325      26083       0.53     0.0325      0.025     0.0184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      4.76G      1.394      2.534     0.9266         15        512: 100%|██████████| 4582/4582 [12:58<00:00,  5.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:36<00:00,  3.44it/s]
#                    all       5325      26083      0.506     0.0488       0.04     0.0295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/150       4.6G       1.51       2.43     0.9603         18        512: 100%|██████████| 4582/4582 [13:28<00:00,  5.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:47<00:00,  3.09it/s]
#                    all       5325      26083      0.568      0.043     0.0452      0.033
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/150      4.59G      1.519      2.338     0.9735          1        512: 100%|██████████| 4582/4582 [15:04<00:00,  5.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:47<00:00,  3.09it/s]
#                    all       5325      26083      0.586     0.0597     0.0615     0.0467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/150      4.61G      1.424      2.126     0.9496         10        512: 100%|██████████| 4582/4582 [16:43<00:00,  4.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [02:04<00:00,  2.69it/s]
#                    all       5325      26083      0.548     0.0819     0.0809     0.0618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/150       4.6G      1.372      2.005     0.9345          3        512: 100%|██████████| 4582/4582 [14:16<00:00,  5.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [02:16<00:00,  2.44it/s]
#                    all       5325      26083      0.533      0.109      0.101      0.079
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/150      4.59G      1.328      1.916     0.9282          7        512: 100%|██████████| 4582/4582 [14:36<00:00,  5.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [02:23<00:00,  2.32it/s]
#                    all       5325      26083      0.502      0.122      0.113     0.0872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/150      4.58G      1.308      1.859     0.9188          4        512: 100%|██████████| 4582/4582 [10:14<00:00,  7.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:20<00:00,  4.14it/s]
#                    all       5325      26083      0.514      0.144      0.126     0.0983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/150       4.6G      1.276       1.81     0.9147         26        512: 100%|██████████| 4582/4582 [09:49<00:00,  7.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:24<00:00,  3.96it/s]
#                    all       5325      26083      0.492      0.153      0.146      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/150       4.6G       1.26      1.749       0.91         27        512: 100%|██████████| 4582/4582 [09:58<00:00,  7.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:13<00:00,  4.53it/s]
#                    all       5325      26083      0.498      0.163      0.158      0.125
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/150       4.6G      1.244      1.721      0.906         26        512: 100%|██████████| 4582/4582 [09:31<00:00,  8.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [00:50<00:00,  6.56it/s]
#                    all       5325      26083      0.464      0.174      0.168      0.132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/150      4.58G      1.225      1.682     0.9016         13        512: 100%|██████████| 4582/4582 [09:35<00:00,  7.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [00:50<00:00,  6.58it/s]
#                    all       5325      26083      0.512      0.177      0.178      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/150       4.6G      1.218       1.65     0.8978         17        512: 100%|██████████| 4582/4582 [09:36<00:00,  7.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [00:50<00:00,  6.62it/s]
#                    all       5325      26083      0.467      0.186      0.188       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/150      4.61G      1.215      1.633     0.8973          3        512: 100%|██████████| 4582/4582 [09:36<00:00,  7.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [00:50<00:00,  6.63it/s]
#                    all       5325      26083      0.495       0.19      0.198      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/150       4.6G      1.205      1.612     0.8952         17        512: 100%|██████████| 4582/4582 [09:38<00:00,  7.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [00:50<00:00,  6.63it/s]
#                    all       5325      26083      0.483      0.199      0.207      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/150      4.58G      1.194      1.589     0.8928          4        512: 100%|██████████| 4582/4582 [09:39<00:00,  7.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [00:50<00:00,  6.57it/s]
#                    all       5325      26083      0.474       0.21      0.215      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/150       4.6G      1.185      1.571     0.8923         15        512: 100%|██████████| 4582/4582 [09:38<00:00,  7.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [00:50<00:00,  6.58it/s]
#                    all       5325      26083      0.486      0.212      0.219      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/150      4.59G      1.179       1.55     0.8916         42        512: 100%|██████████| 4582/4582 [09:47<00:00,  7.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:13<00:00,  4.53it/s]
#                    all       5325      26083      0.463      0.222      0.228      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/150      4.61G       1.17      1.527     0.8913         26        512: 100%|██████████| 4582/4582 [09:44<00:00,  7.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:09<00:00,  4.82it/s]
#                    all       5325      26083      0.486      0.227      0.232      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/150      4.61G      1.163      1.514     0.8876          7        512: 100%|██████████| 4582/4582 [10:03<00:00,  7.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:15<00:00,  4.42it/s]
#                    all       5325      26083      0.467      0.235      0.239      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/150      4.59G      1.162      1.506     0.8875          3        512: 100%|██████████| 4582/4582 [10:44<00:00,  7.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [02:01<00:00,  2.75it/s]
#                    all       5325      26083      0.488      0.235      0.245      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/150      4.59G      1.154      1.484     0.8852          5        512: 100%|██████████| 4582/4582 [12:49<00:00,  5.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:36<00:00,  3.46it/s]
#                    all       5325      26083      0.474      0.242      0.247      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/150       4.6G      1.152      1.478     0.8846          7        512: 100%|██████████| 4582/4582 [11:43<00:00,  6.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:25<00:00,  3.91it/s]
#                    all       5325      26083      0.481      0.247       0.25      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/150      4.58G      1.145      1.465     0.8847         16        512: 100%|██████████| 4582/4582 [10:07<00:00,  7.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:16<00:00,  4.34it/s]
#                    all       5325      26083      0.479      0.249      0.254      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/150      4.61G      1.141      1.446     0.8849          2        512: 100%|██████████| 4582/4582 [10:44<00:00,  7.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:18<00:00,  4.23it/s]
#                    all       5325      26083      0.477       0.25      0.258      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/150       4.6G      1.143      1.443       0.88         13        512: 100%|██████████| 4582/4582 [11:05<00:00,  6.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:30<00:00,  3.68it/s]
#                    all       5325      26083      0.467      0.258      0.259      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/150      4.61G      1.133       1.43     0.8813          9        512: 100%|██████████| 4582/4582 [11:03<00:00,  6.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:28<00:00,  3.78it/s]
#                    all       5325      26083      0.471      0.259      0.262      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/150      4.57G      1.133      1.423     0.8799         10        512: 100%|██████████| 4582/4582 [11:22<00:00,  6.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:32<00:00,  3.60it/s]
#                    all       5325      26083      0.479      0.261      0.264      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/150       4.6G      1.133      1.416     0.8809         13        512: 100%|██████████| 4582/4582 [11:10<00:00,  6.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:28<00:00,  3.78it/s]
#                    all       5325      26083      0.482      0.263      0.266      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/150       4.6G      1.129      1.406     0.8811         20        512: 100%|██████████| 4582/4582 [11:27<00:00,  6.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:30<00:00,  3.69it/s]
#                    all       5325      26083      0.479      0.264      0.268      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/150      4.59G      1.124      1.401     0.8776         21        512: 100%|██████████| 4582/4582 [12:12<00:00,  6.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:35<00:00,  3.49it/s]
#                    all       5325      26083      0.482      0.266      0.269      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/150      4.57G      1.108      1.384     0.8766          9        512: 100%|██████████| 4582/4582 [12:16<00:00,  6.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:30<00:00,  3.66it/s]
#                    all       5325      26083      0.493      0.265      0.271      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/150      4.62G      1.118      1.387     0.8797         13        512: 100%|██████████| 4582/4582 [11:59<00:00,  6.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:39<00:00,  3.33it/s]
#                    all       5325      26083      0.498      0.264      0.272      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/150      4.59G      1.113      1.374     0.8764          7        512: 100%|██████████| 4582/4582 [11:50<00:00,  6.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:29<00:00,  3.71it/s]
#                    all       5325      26083      0.496      0.264      0.273       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/150       4.6G      1.115      1.376     0.8766          5        512: 100%|██████████| 4582/4582 [12:20<00:00,  6.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:39<00:00,  3.34it/s]
#                    all       5325      26083      0.497      0.266      0.276      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/150      4.59G      1.106       1.36      0.875          4        512: 100%|██████████| 4582/4582 [12:45<00:00,  5.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:35<00:00,  3.49it/s]
#                    all       5325      26083      0.497      0.267      0.277      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/150      4.62G      1.108      1.356     0.8749         19        512: 100%|██████████| 4582/4582 [14:41<00:00,  5.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:50<00:00,  3.03it/s]
#                    all       5325      26083      0.498      0.267      0.278      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/150      4.59G      1.106      1.355     0.8737          9        512: 100%|██████████| 4582/4582 [14:19<00:00,  5.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [02:12<00:00,  2.51it/s]
#                    all       5325      26083      0.506      0.264      0.279      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/150      4.61G      1.094      1.336     0.8748          9        512: 100%|██████████| 4582/4582 [14:05<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:38<00:00,  3.39it/s]
#                    all       5325      26083      0.496       0.27      0.279      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/150      4.58G        1.1      1.334     0.8734          5        512: 100%|██████████| 4582/4582 [14:06<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:48<00:00,  3.08it/s]
#                    all       5325      26083      0.504      0.269       0.28      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/150      4.59G       1.09      1.326     0.8717         20        512: 100%|██████████| 4582/4582 [14:03<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:45<00:00,  3.15it/s]
#                    all       5325      26083        0.5      0.272      0.281      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/150       4.6G      1.092      1.321      0.872         19        512: 100%|██████████| 4582/4582 [13:53<00:00,  5.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:43<00:00,  3.20it/s]
#                    all       5325      26083       0.51      0.271      0.283      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/150      4.58G      1.091      1.326     0.8718          3        512: 100%|██████████| 4582/4582 [14:06<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:54<00:00,  2.91it/s]
#                    all       5325      26083      0.512      0.272      0.284      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/150      4.57G       1.09       1.32     0.8728          8        512: 100%|██████████| 4582/4582 [14:55<00:00,  5.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [01:43<00:00,  3.23it/s]
#                    all       5325      26083      0.516      0.272      0.285       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/150      4.59G       1.09       1.31     0.8703         10        512: 100%|██████████| 4582/4582 [15:40<00:00,  4.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [02:07<00:00,  2.60it/s]
#                    all       5325      26083      0.526       0.27      0.286      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/150      4.58G      1.087      1.301     0.8707          5        512: 100%|██████████| 4582/4582 [15:48<00:00,  4.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [02:14<00:00,  2.48it/s]
#                    all       5325      26083      0.532      0.268      0.288      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/150      4.58G      1.087      1.304     0.8713         10        512: 100%|██████████| 4582/4582 [16:06<00:00,  4.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 333/333 [02:23<00:00,  2.33it/s]
#                    all       5325      26083       0.53      0.269      0.288      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/150      4.55G      1.084      1.296     0.8688         43        512:  97%|█████████▋| 4453/4582 [14:59<00:21,  6.00it/s]
